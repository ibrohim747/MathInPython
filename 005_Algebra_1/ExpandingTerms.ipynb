# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrohim747/MathInPython/blob/main/005_Algebra_1/ExpandingTerms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy as sym
from IPython.display import display, Math

# %%
display(Math('a(a+b) = ab + ac'))
# Out:
# $\displaystyle a(a+b) = ab + ac$

# %%
display(Math('(a + b)(c + d) = (ac + ad) + (bc + bd) = ac + ad + bc + bd'))
# Out:
# $\displaystyle (a + b)(c + d) = (ac + ad) + (bc + bd) = ac + ad + bc + bd$

# %%
from sympy.abc import x

term1 = (4*x + 5)
term2 = x

print(term1 * term2)
display(Math(sym.latex(term1 * term2)))
display(Math(sym.latex(sym.expand(term1 * term2))))
# Out:
# x*(4*x + 5)
# $\displaystyle x \left(4 x + 5\right)$
# $\displaystyle 4 x^{2} + 5 x$

# %%
term3 = x - 7
display(Math(sym.latex(term1 * term3)))
display(Math(sym.latex(sym.expand(term1 * term3))))
# Out:
# $\displaystyle \left(x - 7\right) \left(4 x + 5\right)$
# $\displaystyle 4 x^{2} - 23 x - 35$

# %%
from sympy.abc import y

expr = x*(2*y**2 - 5**x/x)
display(Math(sym.latex(expr)))
display(Math(sym.latex(sym.expand(expr))))
# Out:
# $\displaystyle x \left(- \frac{5^{x}}{x} + 2 y^{2}\right)$
# $\displaystyle - 5^{x} + 2 x y^{2}$

# %%
# %whos
# Out:
# Variable   Type        Data/Info
# --------------------------------
# Math       type        <class 'IPython.core.display.Math'>
# display    function    <function display at 0x7c8cb3619e40>
# expr       Mul         x*(-5**x/x + 2*y**2)
# sym        module      <module 'sympy' from '/us<...>kages/sympy/__init__.py'>
# term1      Add         4*x + 5
# term2      Symbol      x
# term3      Add         x - 7
# x          Symbol      x
# y          Symbol      y

# %%
for i in range(0, 3):
    print(num[i])
num = [1,2,6]
#print(len(num))
# Out:
# 1
# 2
# 6

# %%
num = [0, 1, 2]
Fxy = (4+x)*(2-y)
Fxy.subs({x:1, y:0})
# Out:
# 10

# %%
num = range(0,3)
Fxy = (4+x)*(2-y)

for a in range(0, len(num)):
    for b in num:
        print("When x =",a,"y =", b, "f(x, y) =", Fxy.subs({x:a, y:b}))
# Out:
# When x = 0 y = 0 f(x, y) = 8
# When x = 0 y = 1 f(x, y) = 4
# When x = 0 y = 2 f(x, y) = 0
# When x = 1 y = 0 f(x, y) = 10
# When x = 1 y = 1 f(x, y) = 5
# When x = 1 y = 2 f(x, y) = 0
# When x = 2 y = 0 f(x, y) = 12
# When x = 2 y = 1 f(x, y) = 6
# When x = 2 y = 2 f(x, y) = 0
