# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrohim747/MathInPython/blob/main/005_Algebra_1/Associative%2Ccommutative%2Cdistributive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy as sym
import numpy as np
from IPython.display import display, Math

# %% [markdown]
# Associative

# %%
from sympy.abc import x,y

expr1 = x*(4*y)
expr2 = (x*4)*y

# show that two equations are equal by subtracting them!
expr1 - expr2
# Out:
# 0

# %% [markdown]
# Commutative

# %%
e1 = x*4*y
e2 = 4*x*y
e3 = y*x*4

# %%
display( e1.subs(x,3) )

e1.subs({x:2,y:3})
# Out:
# 12*y
# 24

# %%
print( e1.subs({x:3,y:4}) )
print( e2.subs({x:3,y:4}) )
print( e3.subs({x:3,y:4}) )
# Out:
# 48
# 48
# 48

# %% [markdown]
# Distributive

# %%
from sympy.abc import a, b, c, d

expr = (a+b)*(c+d)
expr
# Out:
# (a + b)*(c + d)

# %%
sym.expand(expr)
# Out:
# a*c + a*d + b*c + b*d

# %%
sym.expand( (a+d)*(a-d) )
# Out:
# a**2 - d**2
