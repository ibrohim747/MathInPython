# %% [markdown]
# <a href="https://colab.research.google.com/github/ibrohim747/MathInPython/blob/main/Sympy_03/Sympy_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy as sym
import numpy as np
from IPython.display import display, Math

# %%
x, y = sym.symbols('x, y')
x
# Out:
# x

# %%
y
# Out:
# y

# %%
y + 4
# Out:
# y + 4

# %%
display(x**y)
display(x/y)
# Out:
# x**y
# x/y

# %%
display(np.sqrt(2))
display(sym.sqrt(2))
# Out:
# np.float64(1.4142135623730951)
# sqrt(2)

# %%
display(y * x **2)
# Out:
# x**2*y

# %%
display(sym.sqrt(4)*x)
# Out:
# 2*x

# %%
display(sym.sqrt(x)*sym.sqrt(x))
# Out:
# x
